# %%
import matplotlib.pyplot as plt
char=[10000,20000,40000,80000,100000] 
times=[0.0719,0.1217,0.2246,0.4059,0.5335]

plt.xlabel('Number of Character') 
plt.ylabel('Time Complexity') 
plt.plot(char, times, label ='Finite Automata') 
plt.grid() 
plt.legend() 
plt.show()
