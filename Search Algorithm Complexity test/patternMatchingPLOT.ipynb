# %%
import matplotlib.pyplot as plt
characters=[10000,20000,40000,80000,100000] 
times=[0.0165,0.0203,0.0443,0.1346,0.1438]

c=[10000,20000,40000,80000,100000] 
t=[0.0128,0.0189,0.0277,0.0663,0.1005]

ch=[10000,20000,40000,80000,100000] 
ti=[0.0719,0.1217,0.2246,0.4059,0.5335]

char=[10000,20000,40000,80000,100000] 
tim=[0.0193,0.0327,0.0514,0.0971,0.1138]

plt.xlabel('Number of Character') 
plt.ylabel('Time Complexity') 
plt.plot(characters, times, label ='Naive Algorithm') 
plt.plot(c, t,color='r', label ='KMP Algorithm') 
plt.plot(ch, ti,color='y',label ='Finite Automata') 
plt.plot(char, tim,color='g', label =' Rabin-Karp algorithm') 
plt.grid() 
plt.legend() 
plt.show()
