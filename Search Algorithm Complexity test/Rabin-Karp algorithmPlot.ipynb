# %%
import matplotlib.pyplot as plt
characters=[10000,20000,40000,80000,100000] 
times=[0.0193,0.0327,0.0514,0.0971,0.1138]

plt.xlabel('Number of Character') 
plt.ylabel('Time Complexity') 
plt.plot(characters, times, label =' Rabin-Karp algorithm') 
plt.grid() 
plt.legend() 
plt.show()
