# %%
import matplotlib.pyplot as plt
word=[10000,20000,40000,80000,100000] 
times=[0.0120,0.0201,0.0407,0.0780,0.0891]

plt.xlabel('Number of words') 
plt.ylabel('Time Complexity') 
plt.plot(word, times, label ='Linear search') 
plt.grid() 
plt.legend() 
plt.show()
