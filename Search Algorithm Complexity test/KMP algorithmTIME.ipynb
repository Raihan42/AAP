# %%
import time 
def KMPSearch(pat, txt): 
    
    M = len(pat) 
    N = len(txt) 
  
    # create lps[] that will hold the longest prefix suffix  
    # values for pattern 
    lps = [0]*M 
    j = 0 # index for pat[] 
  
    # Preprocess the pattern (calculate lps[] array) 
    computeLPSArray(pat, M, lps) 
  
    i = 0 # index for txt[] 
    while i < N: 
        if pat[j] == txt[i]: 
            i += 1
            j += 1
  
        if j == M: 
            print ("Found pattern at index " + str(i-j)) 
            
            end = time.clock()
            print(end)
            print(end-start)
            j = lps[j-1] 
  
        # mismatch after j matches 
        elif i < N and pat[j] != txt[i]: 
            # Do not match lps[0..lps[j-1]] characters, 
            # they will match anyway 
            if j != 0: 
                j = lps[j-1] 
            else: 
                i += 1

start = time.clock() 

print(start)

 
  
def computeLPSArray(pat, M, lps): 
    len = 0 # length of the previous longest prefix suffix 
  
    lps[0] # lps[0] is always 0 
    i = 1
  
    # the loop calculates lps[i] for i = 1 to M-1 
    while i < M: 
        if pat[i]== pat[len]: 
            len += 1
            lps[i] = len
            i += 1
        else: 
            
            if len != 0: 
                len = lps[len-1] 
  
            else: 
                lps[i] = 0
                i += 1
                
    
txt = "অংশকঅংশঅঅংশকঅংশঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশকল্পনাকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশকল্পনাকল্পনাকঅংশকল্পনাঅঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশকল্পনাকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশকল্পনাকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশকল্পনাকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশকল্পনাকল্পনাংশকঅংশকল্পনাঅঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশকল্পনাকল্পনাকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশকল্পনাকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশকল্পনাকল্পনাঅংশকঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকঅংশঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশকঅংশকল্পনাঅংশককঅংশকল্পনাকল্পনাঅংশগত"
pat = "অংশগত"
KMPSearch(pat, txt)
# Out:
# 21195.2769651
# Found pattern at index 99837
# 21195.3775141
# 0.10054899999886402
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:38: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
