# %%
import matplotlib.pyplot as plt
character=[10000,20000,40000,80000,100000] 
times=[0.0128,0.0189,0.0277,0.0663,0.1005]

plt.xlabel('Number of Character') 
plt.ylabel('Time Complexity') 
plt.plot(character, times, label ='KMP Algorithm') 
plt.grid() 
plt.legend() 
plt.show()
